# %% [markdown]
# # Active Suspension Control

# %% [markdown]
# ![image.png](attachment:image.png)
#
# State: $ (x_1, x_2, x_3, x_4) = (x_b, \dot{x_b}, x_w, \dot{x_w}) $
#
# Control input: $ u = f_s $
